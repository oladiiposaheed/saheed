# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('covidnig.csv')

# %%
df
# Out:
#    States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# 0            Lagos                       26,708                       2,435
# 1              FCT                        9,627                       2,840
# 2           Kaduna                        4,504                         579
# 3          Plateau                        4,262                         280
# 4              Oyo                        3,788                         368
# 5           Rivers                        3,279                         232
# 6              Edo                        2,768                          52
# 7             Ogun                        2,382                         174
# 8             Kano                        2,032                         198
# 9            Delta                        1,843                          57
# 10            Ondo                        1,793                          62
# ...

# %%
#View the first couple of rowa using head()
df.head()
# Out:
#   States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# 0           Lagos                       26,708                       2,435
# 1             FCT                        9,627                       2,840
# 2          Kaduna                        4,504                         579
# 3         Plateau                        4,262                         280
# 4             Oyo                        3,788                         368
#
#   No. Discharged  No. of Deaths
# 0         24,037            236
# 1          6,694             93
# 2          3,877             48
# 3          3,948             34
# 4          3,374             46

# %%
#View the last couple of rows using tail()
df.tail()
# Out:
#    States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# 32            Yobe                          164                          33
# 33           Kebbi                          143                           5
# 34     Cross River                           93                           1
# 35        Zamfara                            79                           1
# 36            Kogi                            5                           0
#
#    No. Discharged  No. of Deaths
# 32            123              8
# 33            130              8
# 34             81             11
# 35             73              5
# 36              3              2

# %%
#Obtain the shape of the DataFrame
df.shape
# Out:
# (37, 5)

# %% [markdown]
# From the above output, we conclude that we have 37 rows and 5 columns (37, 5)

# %%
#Obtain DataFrame information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   States Affected               37 non-null     object
#  1   No. of Cases (Lab Confirmed)  37 non-null     object
#  2   No. of Cases (on admission)   37 non-null     object
#  3   No. Discharged                37 non-null     object
#  4   No. of Deaths                 37 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 1.6+ KB

# %%
#Extract only the affected state in Nigeria
df['States Affected']
# Out:
# 0           Lagos
# 1             FCT
# 2          Kaduna
# 3         Plateau
# 4             Oyo
# 5          Rivers
# 6             Edo
# 7            Ogun
# 8            Kano
# 9           Delta
# 10           Ondo
# 11        Katsina
# 12          Enugu
# 13          Kwara
# 14          Gombe
# 15         Ebonyi
# 16           Abia
# 17           Osun
# 18         Bauchi
# 19          Borno
# 20            Imo
# 21       Nasarawa
# 22          Benue
# 23        Bayelsa
# 24          Ekiti
# 25      Akwa Ibom
# 26         Jigawa
# 27          Niger
# 28        Adamawa
# 29        Anambra
# 30         Sokoto
# 31         Taraba
# 32           Yobe
# 33          Kebbi
# 34    Cross River
# 35       Zamfara
# 36           Kogi
# Name: States Affected, dtype: object

# %%
df['States Affected'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 37 entries, 0 to 36
# Series name: States Affected
# Non-Null Count  Dtype
# --------------  -----
# 37 non-null     object
# dtypes: object(1)
# memory usage: 424.0+ bytes

# %%
df = pd.read_csv('covidnig.csv')
df
# Out:
#    States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# 0            Lagos                       26,708                       2,435
# 1              FCT                        9,627                       2,840
# 2           Kaduna                        4,504                         579
# 3          Plateau                        4,262                         280
# 4              Oyo                        3,788                         368
# 5           Rivers                        3,279                         232
# 6              Edo                        2,768                          52
# 7             Ogun                        2,382                         174
# 8             Kano                        2,032                         198
# 9            Delta                        1,843                          57
# 10            Ondo                        1,793                          62
# ...

# %%
#Assign a specific column to be the index using: set_index
df.set_index('States Affected', inplace=True)
df
# Out:
#                 No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# States Affected
# Lagos                                 26,708                       2,435
# FCT                                    9,627                       2,840
# Kaduna                                 4,504                         579
# Plateau                                4,262                         280
# Oyo                                    3,788                         368
# Rivers                                 3,279                         232
# Edo                                    2,768                          52
# Ogun                                   2,382                         174
# Kano                                   2,032                         198
# Delta                                  1,843                          57
# Ondo                                   1,793                          62
# Katsina                                1,405                         214
# ...

# %%
# Read the dataset file again
df = pd.read_csv('covidnig.csv')
df
# Out:
#    States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# 0            Lagos                       26,708                       2,435
# 1              FCT                        9,627                       2,840
# 2           Kaduna                        4,504                         579
# 3          Plateau                        4,262                         280
# 4              Oyo                        3,788                         368
# 5           Rivers                        3,279                         232
# 6              Edo                        2,768                          52
# 7             Ogun                        2,382                         174
# 8             Kano                        2,032                         198
# 9            Delta                        1,843                          57
# 10            Ondo                        1,793                          62
# ...

# %%
# OR
df = pd.read_csv('covidnig.csv', index_col='States Affected')
df
# Out:
#                 No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# States Affected
# Lagos                                 26,708                       2,435
# FCT                                    9,627                       2,840
# Kaduna                                 4,504                         579
# Plateau                                4,262                         280
# Oyo                                    3,788                         368
# Rivers                                 3,279                         232
# Edo                                    2,768                          52
# Ogun                                   2,382                         174
# Kano                                   2,032                         198
# Delta                                  1,843                          57
# Ondo                                   1,793                          62
# Katsina                                1,405                         214
# ...

# %%
# Read the dataset file again
df = pd.read_csv('covidnig.csv')
df
# Out:
#    States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# 0            Lagos                       26,708                       2,435
# 1              FCT                        9,627                       2,840
# 2           Kaduna                        4,504                         579
# 3          Plateau                        4,262                         280
# 4              Oyo                        3,788                         368
# 5           Rivers                        3,279                         232
# 6              Edo                        2,768                          52
# 7             Ogun                        2,382                         174
# 8             Kano                        2,032                         198
# 9            Delta                        1,843                          57
# 10            Ondo                        1,793                          62
# ...

# %%
#Extract only the affected states, no of cases lab confirmed and no of cases on admission
df = df[ ['States Affected', 'No. of Cases (Lab Confirmed)', 'No. of Cases (on admission)'] ]
df
# Out:
#    States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)
# 0            Lagos                       26,708                       2,435
# 1              FCT                        9,627                       2,840
# 2           Kaduna                        4,504                         579
# 3          Plateau                        4,262                         280
# 4              Oyo                        3,788                         368
# 5           Rivers                        3,279                         232
# 6              Edo                        2,768                          52
# 7             Ogun                        2,382                         174
# 8             Kano                        2,032                         198
# 9            Delta                        1,843                          57
# 10            Ondo                        1,793                          62
# ...

# %%
df = pd.read_csv('covidnig.csv')
df.head()
# Out:
#   States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# 0           Lagos                       26,708                       2,435
# 1             FCT                        9,627                       2,840
# 2          Kaduna                        4,504                         579
# 3         Plateau                        4,262                         280
# 4             Oyo                        3,788                         368
#
#   No. Discharged  No. of Deaths
# 0         24,037            236
# 1          6,694             93
# 2          3,877             48
# 3          3,948             34
# 4          3,374             46

# %%
#Extract only the affected states, no of cases lab confirmed and no of cases on admission
df = df[ ['States Affected', 'No. Discharged', 'No. of Deaths'] ]
df
# Out:
#    States Affected No. Discharged  No. of Deaths
# 0            Lagos         24,037            236
# 1              FCT          6,694             93
# 2           Kaduna          3,877             48
# 3          Plateau          3,948             34
# 4              Oyo          3,374             46
# 5           Rivers          2,987             60
# 6              Edo          2,603            113
# 7             Ogun          2,175             33
# 8             Kano          1,778             56
# 9            Delta          1,737             49
# 10            Ondo          1,690             41
# 11         Katsina          1,167             24
# 12           Enugu          1,321             21
# 13           Kwara          1,094             31
# 14           Gombe            950             31
# 15          Ebonyi          1,037             30
# 16            Abia            945             10
# 17            Osun            937             22
# ...

# %%
#Extract only the affected states, and no of deaths
df = df[ ['States Affected', 'No. of Deaths'] ]
df
# Out:
#    States Affected  No. of Deaths
# 0            Lagos            236
# 1              FCT             93
# 2           Kaduna             48
# 3          Plateau             34
# 4              Oyo             46
# 5           Rivers             60
# 6              Edo            113
# 7             Ogun             33
# 8             Kano             56
# 9            Delta             49
# 10            Ondo             41
# 11         Katsina             24
# 12           Enugu             21
# 13           Kwara             31
# 14           Gombe             31
# 15          Ebonyi             30
# 16            Abia             10
# 17            Osun             22
# 18          Bauchi             14
# 19           Borno             36
# 20             Imo             12
# 21        Nasarawa             13
# 22           Benue             11
# 23         Bayelsa             21
# 24           Ekiti              6
# 25       Akwa Ibom              9
# ...

# %%
df = pd.read_csv('covidnig.csv')
df.tail()
# Out:
#    States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# 32            Yobe                          164                          33
# 33           Kebbi                          143                           5
# 34     Cross River                           93                           1
# 35        Zamfara                            79                           1
# 36            Kogi                            5                           0
#
#    No. Discharged  No. of Deaths
# 32            123              8
# 33            130              8
# 34             81             11
# 35             73              5
# 36              3              2

# %%
#Extract only the affected states, and number of discharged
df = df[ ['States Affected', 'No. Discharged'] ]
df
# Out:
#    States Affected No. Discharged
# 0            Lagos         24,037
# 1              FCT          6,694
# 2           Kaduna          3,877
# 3          Plateau          3,948
# 4              Oyo          3,374
# 5           Rivers          2,987
# 6              Edo          2,603
# 7             Ogun          2,175
# 8             Kano          1,778
# 9            Delta          1,737
# 10            Ondo          1,690
# 11         Katsina          1,167
# 12           Enugu          1,321
# 13           Kwara          1,094
# 14           Gombe            950
# 15          Ebonyi          1,037
# 16            Abia            945
# 17            Osun            937
# 18          Bauchi            775
# 19           Borno            705
# 20             Imo            661
# 21        Nasarawa            325
# 22           Benue            460
# 23         Bayelsa            421
# 24           Ekiti            375
# 25       Akwa Ibom            342
# ...

# %%
#Extract the fourth ten state based on states affected and the no of discharged
df[4: 11]
# Out:
#    States Affected No. Discharged
# 4              Oyo          3,374
# 5           Rivers          2,987
# 6              Edo          2,603
# 7             Ogun          2,175
# 8             Kano          1,778
# 9            Delta          1,737
# 10            Ondo          1,690

# %%
df = pd.read_csv('covidnig.csv')
df.head(3)
# Out:
#   States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# 0           Lagos                       26,708                       2,435
# 1             FCT                        9,627                       2,840
# 2          Kaduna                        4,504                         579
#
#   No. Discharged  No. of Deaths
# 0         24,037            236
# 1          6,694             93
# 2          3,877             48

# %%
#Extract the fourth ten state 
df[4: 11]
# Out:
#    States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# 4              Oyo                        3,788                         368
# 5           Rivers                        3,279                         232
# 6              Edo                        2,768                          52
# 7             Ogun                        2,382                         174
# 8             Kano                        2,032                         198
# 9            Delta                        1,843                          57
# 10            Ondo                        1,793                          62
#
#    No. Discharged  No. of Deaths
# 4           3,374             46
# 5           2,987             60
# 6           2,603            113
# 7           2,175             33
# 8           1,778             56
# 9           1,737             49
# 10          1,690             41

# %%
#Extract the tenth eighteen state 
df[10: 19]
# Out:
#    States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# 10            Ondo                        1,793                          62
# 11         Katsina                        1,405                         214
# 12           Enugu                        1,376                          34
# 13           Kwara                        1,296                         171
# 14           Gombe                        1,164                         183
# 15          Ebonyi                        1,091                          24
# 16            Abia                          980                          25
# 17            Osun                          979                          20
# 18          Bauchi                          897                         108
#
#    No. Discharged  No. of Deaths
# 10          1,690             41
# 11          1,167             24
# 12          1,321             21
# 13          1,094             31
# 14            950             31
# ...

# %%
#Extract the first 36 even states
df[0: 36 : 2]
# Out:
#    States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# 0            Lagos                       26,708                       2,435
# 2           Kaduna                        4,504                         579
# 4              Oyo                        3,788                         368
# 6              Edo                        2,768                          52
# 8             Kano                        2,032                         198
# 10            Ondo                        1,793                          62
# 12           Enugu                        1,376                          34
# 14           Gombe                        1,164                         183
# 16            Abia                          980                          25
# 18          Bauchi                          897                         108
# 20             Imo                          734                          61
# ...

# %% [markdown]
# Sort state in alphabetical order in ascending order

# %%
df = pd.read_csv('covidnig.csv', index_col='States Affected')
df
# Out:
#                 No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# States Affected
# Lagos                                 26,708                       2,435
# FCT                                    9,627                       2,840
# Kaduna                                 4,504                         579
# Plateau                                4,262                         280
# Oyo                                    3,788                         368
# Rivers                                 3,279                         232
# Edo                                    2,768                          52
# Ogun                                   2,382                         174
# Kano                                   2,032                         198
# Delta                                  1,843                          57
# Ondo                                   1,793                          62
# Katsina                                1,405                         214
# ...

# %%
df.sort_index(inplace=True)
df
# Out:
#                 No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# States Affected
# Abia                                     980                          25
# Adamawa                                  355                          96
# Akwa Ibom                                395                          44
# Anambra                                  299                           6
# Bauchi                                   897                         108
# Bayelsa                                  497                          55
# Benue                                    515                          44
# Borno                                    778                          37
# Cross River                               93                           1
# Delta                                  1,843                          57
# Ebonyi                                 1,091                          24
# Edo                                    2,768                          52
# ...

# %% [markdown]
# Sort state in alphabetical order in descending order

# %%
df.sort_index(inplace=True,ascending=False )
df
# Out:
#                 No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# States Affected
# Zamfara                                   79                           1
# Yobe                                     164                          33
# Taraba                                   203                          19
# Sokoto                                   228                          40
# Rivers                                 3,279                         232
# Plateau                                4,262                         280
# Oyo                                    3,788                         368
# Osun                                     979                          20
# Ondo                                   1,793                          62
# Ogun                                   2,382                         174
# Niger                                    381                          69
# Nasarawa                                 600                         262
# ...

# %%
#Get information about lagos state only
df.loc['Lagos']
# Out:
# No. of Cases (Lab Confirmed)    26,708
# No. of Cases (on admission)      2,435
# No. Discharged                  24,037
# No. of Deaths                      236
# Name: Lagos, dtype: object

# %%
#Get information about Anambra state only
df.loc['Anambra']
# Out:
# No. of Cases (Lab Confirmed)    299
# No. of Cases (on admission)       6
# No. Discharged                  274
# No. of Deaths                    19
# Name: Anambra, dtype: object

# %%
#Get information about Anambra state only
df.loc['Bauchi']
# Out:
# No. of Cases (Lab Confirmed)    897
# No. of Cases (on admission)     108
# No. Discharged                  775
# No. of Deaths                    14
# Name: Bauchi, dtype: object

# %%
#Extract information of all states between katsina and ekiti states
df.loc['Katsina' : 'Ekiti']
# Out:
#                 No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# States Affected
# Katsina                                1,405                         214
# Kano                                   2,032                         198
# Kaduna                                 4,504                         579
# Jigawa                                   386                          57
# Imo                                      734                          61
# Gombe                                  1,164                         183
# FCT                                    9,627                       2,840
# Enugu                                  1,376                          34
# Ekiti                                    405                          24
#
#                 No. Discharged  No. of Deaths
# States Affected
# Katsina                  1,167             24
# Kano                     1,778             56
# Kaduna                   3,877             48
# ...

# %%
#Extract information of all states between osun and delta states
df.loc['Osun' : 'Kebbi']
# Out:
#                 No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# States Affected
# Osun                                     979                          20
# Ondo                                   1,793                          62
# Ogun                                   2,382                         174
# Niger                                    381                          69
# Nasarawa                                 600                         262
# Lagos                                 26,708                       2,435
# Kwara                                  1,296                         171
# Kogi                                       5                           0
# Kebbi                                    143                           5
#
#                 No. Discharged  No. of Deaths
# States Affected
# Osun                       937             22
# Ondo                     1,690             41
# Ogun                     2,175             33
# ...

# %%
#Extract information of the states ondo, ogun, kano and kogi and enugu states
df.loc[['Ondo', 'Ogun', 'Kano', 'Kogi', 'Enugu']]
# Out:
#                 No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# States Affected
# Ondo                                   1,793                          62
# Ogun                                   2,382                         174
# Kano                                   2,032                         198
# Kogi                                       5                           0
# Enugu                                  1,376                          34
#
#                 No. Discharged  No. of Deaths
# States Affected
# Ondo                     1,690             41
# Ogun                     2,175             33
# Kano                     1,778             56
# Kogi                         3              2
# Enugu                    1,321             21

# %%
#Select any four states
df.sample(n = 4, axis = 0)
# Out:
#                 No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# States Affected
# Oyo                                    3,788                         368
# Edo                                    2,768                          52
# Enugu                                  1,376                          34
# Lagos                                 26,708                       2,435
#
#                 No. Discharged  No. of Deaths
# States Affected
# Oyo                      3,374             46
# Edo                      2,603            113
# Enugu                    1,321             21
# Lagos                   24,037            236

# %%
# Get information of the 4th state in the dataset
df.iloc[3]
# Out:
# No. of Cases (Lab Confirmed)    228
# No. of Cases (on admission)      40
# No. Discharged                  171
# No. of Deaths                    17
# Name: Sokoto, dtype: object

# %%
# Get the data information of the 5th, 35th and 1st state in the dataset
df.iloc[[4, 34, 1]]
# Out:
#    States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# 4              Oyo                         3788                         368
# 34     Cross River                           93                           1
# 1              FCT                         9627                        2840
#
#    No. Discharged  No. of Deaths
# 4            3374             46
# 34             81             11
# 1            6694             93

# %%
# Get the last data information in the dataset
df.iloc[-1]
# Out:
# No. of Cases (Lab Confirmed)    980
# No. of Cases (on admission)      25
# No. Discharged                  945
# No. of Deaths                    10
# Name: Abia, dtype: object

# %%
df.iloc[:6]
# Out:
#                 No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# States Affected
# Zamfara                                   79                           1
# Yobe                                     164                          33
# Taraba                                   203                          19
# Sokoto                                   228                          40
# Rivers                                 3,279                         232
# Plateau                                4,262                         280
#
#                 No. Discharged  No. of Deaths
# States Affected
# Zamfara                     73              5
# Yobe                       123              8
# Taraba                     177              7
# Sokoto                     171             17
# Rivers                   2,987             60
# Plateau                  3,948             34

# %%
# Get the last 29th data information in the dataset
df.iloc[29:]
# Out:
#                 No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# States Affected
# Borno                                    778                          37
# Benue                                    515                          44
# Bayelsa                                  497                          55
# Bauchi                                   897                         108
# Anambra                                  299                           6
# Akwa Ibom                                395                          44
# Adamawa                                  355                          96
# Abia                                     980                          25
#
#                 No. Discharged  No. of Deaths
# States Affected
# Borno                      705             36
# Benue                      460             11
# Bayelsa                    421             21
# Bauchi                     775             14
# ...

# %%
#Select the 11th row in the data information with the first 3 columns
df.iloc[10, 0:2]
# Out:
# No. of Cases (Lab Confirmed)    381
# No. of Cases (on admission)      69
# Name: Niger, dtype: object

# %%
#Select the 1st row in the data information with the first 5 columns
df.iloc[0, 0:4]
# Out:
# No. of Cases (Lab Confirmed)    79
# No. of Cases (on admission)      1
# No. Discharged                  73
# No. of Deaths                    5
# Name: Zamfara , dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37 entries, Zamfara  to Abia
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   No. of Cases (Lab Confirmed)  37 non-null     object
#  1   No. of Cases (on admission)   37 non-null     object
#  2   No. Discharged                37 non-null     object
#  3   No. of Deaths                 37 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 2.5+ KB

# %%
# Reduce the number of death for each state by 10%
df['New No. of Death'] = round(df['No. of Deaths'] * 0.9)
df
del df['New No. of Death']

df['New No. of Death'] = round(df['No. of Deaths'] * 0.9)
del df['New No. of Death']

# %%
df
# Out:
#                 No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# States Affected
# Zamfara                                   79                           1
# Yobe                                     164                          33
# Taraba                                   203                          19
# Sokoto                                   228                          40
# Rivers                                 3,279                         232
# Plateau                                4,262                         280
# Oyo                                    3,788                         368
# Osun                                     979                          20
# Ondo                                   1,793                          62
# Ogun                                   2,382                         174
# Niger                                    381                          69
# Nasarawa                                 600                         262
# ...

# %%
df['New No. of Deaths'] = round(df['No. of Deaths'] * 0.9)
del df['New No. of Deaths']
df
# Out:
#                 No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# States Affected
# Zamfara                                   79                           1
# Yobe                                     164                          33
# Taraba                                   203                          19
# Sokoto                                   228                          40
# Rivers                                 3,279                         232
# Plateau                                4,262                         280
# Oyo                                    3,788                         368
# Osun                                     979                          20
# Ondo                                   1,793                          62
# Ogun                                   2,382                         174
# Niger                                    381                          69
# Nasarawa                                 600                         262
# ...

# %%
#Check the number of null values in the data in bool form
df.isnull()
# Out:
#                  No. of Cases (Lab Confirmed)  No. of Cases (on admission)  \
# States Affected
# Zamfara                                 False                        False
# Yobe                                    False                        False
# Taraba                                  False                        False
# Sokoto                                  False                        False
# Rivers                                  False                        False
# Plateau                                 False                        False
# Oyo                                     False                        False
# Osun                                    False                        False
# Ondo                                    False                        False
# Ogun                                    False                        False
# Niger                                   False                        False
# ...

# %%
#Check the number of null values in the data
df.isnull().sum()
# Out:
# No. of Cases (Lab Confirmed)    0
# No. of Cases (on admission)     0
# No. Discharged                  0
# No. of Deaths                   0
# New No. of Death                0
# dtype: int64

# %% [markdown]
# From the output above, it shows that no missing data

# %%
df = pd.read_csv('covidnig.csv')
df.head()
# Out:
#   States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# 0           Lagos                       26,708                       2,435
# 1             FCT                        9,627                       2,840
# 2          Kaduna                        4,504                         579
# 3         Plateau                        4,262                         280
# 4             Oyo                        3,788                         368
#
#   No. Discharged  No. of Deaths
# 0         24,037            236
# 1          6,694             93
# 2          3,877             48
# 3          3,948             34
# 4          3,374             46

# %%
# Extract the unique affected State 
df['States Affected'].unique()
# Out:
# array(['Lagos', 'FCT', 'Kaduna', 'Plateau', 'Oyo', 'Rivers', 'Edo',
#        'Ogun', 'Kano', 'Delta', 'Ondo', 'Katsina', 'Enugu', 'Kwara',
#        'Gombe', 'Ebonyi', 'Abia', 'Osun', 'Bauchi', 'Borno', 'Imo',
#        'Nasarawa', 'Benue', 'Bayelsa', 'Ekiti', 'Akwa Ibom', 'Jigawa',
#        'Niger', 'Adamawa', 'Anambra', 'Sokoto', 'Taraba', 'Yobe', 'Kebbi',
#        'Cross River', 'Zamfara ', 'Kogi'], dtype=object)

# %%
# Extract the uniques affected State 
type(df['States Affected'].unique())
# Out:
# numpy.ndarray

# %%
# Extract the total affected State 
print('There are {} afftectd states in Nigeria'.format(df['States Affected'].nunique()))
# Out:
# There are 37 afftectd states in Nigeria

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   States Affected               37 non-null     object
#  1   No. of Cases (Lab Confirmed)  37 non-null     object
#  2   No. of Cases (on admission)   37 non-null     object
#  3   No. Discharged                37 non-null     object
#  4   No. of Deaths                 37 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 1.6+ KB

# %%
#Select all the no of death based on States affeted
df.groupby('States Affected')['No. of Deaths'].mean()
# Out:
# States Affected
# Abia            10.0
# Adamawa         21.0
# Akwa Ibom        9.0
# Anambra         19.0
# Bauchi          14.0
# Bayelsa         21.0
# Benue           11.0
# Borno           36.0
# Cross River     11.0
# Delta           49.0
# Ebonyi          30.0
# Edo            113.0
# Ekiti            6.0
# Enugu           21.0
# FCT             93.0
# Gombe           31.0
# Imo             12.0
# Jigawa          11.0
# Kaduna          48.0
# Kano            56.0
# Katsina         24.0
# Kebbi            8.0
# Kogi             2.0
# Kwara           31.0
# Lagos          236.0
# Nasarawa        13.0
# Niger           12.0
# Ogun            33.0
# Ondo            41.0
# Osun            22.0
# Oyo             46.0
# Plateau         34.0
# Rivers          60.0
# Sokoto          17.0
# Taraba           7.0
# Yobe             8.0
# Zamfara          5.0
# Name: No. of Deaths, dtype: float64

# %%
df = pd.read_csv('covidnig.csv')
df.head(2)
# Out:
#   States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# 0           Lagos                       26,708                       2,435
# 1             FCT                        9,627                       2,840
#
#   No. Discharged  No. of Deaths
# 0         24,037            236
# 1          6,694             93

# %%
# Select States affected and No. of Deaths to be the the index for the dataframe
df.set_index(keys = ['States Affected', 'No. of Deaths'], inplace=True)
df
# Out:
#                               No. of Cases (Lab Confirmed)  \
# States Affected No. of Deaths
# Lagos           236                                 26,708
# FCT             93                                   9,627
# Kaduna          48                                   4,504
# Plateau         34                                   4,262
# Oyo             46                                   3,788
# Rivers          60                                   3,279
# Edo             113                                  2,768
# Ogun            33                                   2,382
# Kano            56                                   2,032
# Delta           49                                   1,843
# Ondo            41                                   1,793
# Katsina         24                                   1,405
# Enugu           21                                   1,376
# Kwara           31                                   1,296
# ...

# %%
#Extract the first level of the index
df.index.get_level_values(1)
# Out:
# Int64Index([236,  93,  48,  34,  46,  60, 113,  33,  56,  49,  41,  24,  21,
#              31,  31,  30,  10,  22,  14,  36,  12,  13,  11,  21,   6,   9,
#              11,  12,  21,  19,  17,   7,   8,   8,  11,   5,   2],
#            dtype='int64', name='No. of Deaths')

# %%
#Extract the first level of the index
df.index.get_level_values(0)
# Out:
# Index(['Lagos', 'FCT', 'Kaduna', 'Plateau', 'Oyo', 'Rivers', 'Edo', 'Ogun',
#        'Kano', 'Delta', 'Ondo', 'Katsina', 'Enugu', 'Kwara', 'Gombe', 'Ebonyi',
#        'Abia', 'Osun', 'Bauchi', 'Borno', 'Imo', 'Nasarawa', 'Benue',
#        'Bayelsa', 'Ekiti', 'Akwa Ibom', 'Jigawa', 'Niger', 'Adamawa',
#        'Anambra', 'Sokoto', 'Taraba', 'Yobe', 'Kebbi', 'Cross River',
#        'Zamfara ', 'Kogi'],
#       dtype='object', name='States Affected')

# %%
#Extract the last level of the index
df.index.get_level_values(-1)
# Out:
# Int64Index([236,  93,  48,  34,  46,  60, 113,  33,  56,  49,  41,  24,  21,
#              31,  31,  30,  10,  22,  14,  36,  12,  13,  11,  21,   6,   9,
#              11,  12,  21,  19,  17,   7,   8,   8,  11,   5,   2],
#            dtype='int64', name='No. of Deaths')

# %%
#Extract the last level of the index
df.index.get_level_values('No. of Deaths')
# Out:
# Int64Index([236,  93,  48,  34,  46,  60, 113,  33,  56,  49,  41,  24,  21,
#              31,  31,  30,  10,  22,  14,  36,  12,  13,  11,  21,   6,   9,
#              11,  12,  21,  19,  17,   7,   8,   8,  11,   5,   2],
#            dtype='int64', name='No. of Deaths')

# %%
df = pd.read_csv('covidnig.csv')
df
# Out:
#    States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# 0            Lagos                       26,708                       2,435
# 1              FCT                        9,627                       2,840
# 2           Kaduna                        4,504                         579
# 3          Plateau                        4,262                         280
# 4              Oyo                        3,788                         368
# 5           Rivers                        3,279                         232
# 6              Edo                        2,768                          52
# 7             Ogun                        2,382                         174
# 8             Kano                        2,032                         198
# 9            Delta                        1,843                          57
# 10            Ondo                        1,793                          62
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   States Affected               37 non-null     object
#  1   No. of Cases (Lab Confirmed)  37 non-null     object
#  2   No. of Cases (on admission)   37 non-null     object
#  3   No. Discharged                37 non-null     object
#  4   No. of Deaths                 37 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 1.6+ KB

# %%
df = pd.read_csv('covidnig.csv')
df.head(2)
# Out:
#   States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# 0           Lagos                       26,708                       2,435
# 1             FCT                        9,627                       2,840
#
#   No. Discharged  No. of Deaths
# 0         24,037            236
# 1          6,694             93

# %% [markdown]
# Cleaning of data

# %%
#df['No. of Cases (Lab Confirmed)'] = pd.to_numeric(df['No. of Cases (Lab Confirmed)'])
#df['No. of Cases (Lab Confirmed)'] = df['No. of Cases (Lab Confirmed)'].astype(str).astype(int)

# %%
# Remove the comma in No. of Cases (Lab Confirmed) column
df['No. of Cases (Lab Confirmed)']=df['No. of Cases (Lab Confirmed)'].str.replace(',','')
df
# Out:
#    States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# 0            Lagos                        26708                       2,435
# 1              FCT                         9627                       2,840
# 2           Kaduna                         4504                         579
# 3          Plateau                         4262                         280
# 4              Oyo                         3788                         368
# 5           Rivers                         3279                         232
# 6              Edo                         2768                          52
# 7             Ogun                         2382                         174
# 8             Kano                         2032                         198
# 9            Delta                         1843                          57
# 10            Ondo                         1793                          62
# ...

# %%
# Remove the comma in No. of Cases (on admission) column
df['No. of Cases (on admission)']=df['No. of Cases (on admission)'].str.replace(',','')
df
# Out:
#    States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# 0            Lagos                        26708                        2435
# 1              FCT                         9627                        2840
# 2           Kaduna                         4504                         579
# 3          Plateau                         4262                         280
# 4              Oyo                         3788                         368
# 5           Rivers                         3279                         232
# 6              Edo                         2768                          52
# 7             Ogun                         2382                         174
# 8             Kano                         2032                         198
# 9            Delta                         1843                          57
# 10            Ondo                         1793                          62
# ...

# %%
# Remove the comma in No. of Cases (on admission) column
df['No. Discharged']=df['No. Discharged'].str.replace(',','')
df
# Out:
#    States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# 0            Lagos                        26708                        2435
# 1              FCT                         9627                        2840
# 2           Kaduna                         4504                         579
# 3          Plateau                         4262                         280
# 4              Oyo                         3788                         368
# 5           Rivers                         3279                         232
# 6              Edo                         2768                          52
# 7             Ogun                         2382                         174
# 8             Kano                         2032                         198
# 9            Delta                         1843                          57
# 10            Ondo                         1793                          62
# ...

# %% [markdown]
# Convert all the column objects to integer

# %%
#Convert No. of Cases (Lab Confirmed) object to integer
df['No. of Cases (Lab Confirmed)'] = df['No. of Cases (Lab Confirmed)'].astype(str).astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   States Affected               37 non-null     object
#  1   No. of Cases (Lab Confirmed)  37 non-null     int32
#  2   No. of Cases (on admission)   37 non-null     object
#  3   No. Discharged                37 non-null     object
#  4   No. of Deaths                 37 non-null     int64
# dtypes: int32(1), int64(1), object(3)
# memory usage: 1.4+ KB

# %%
#Convert No. of Cases (on admission) object to integer
df['No. of Cases (on admission)'] = df['No. of Cases (on admission)'].astype(str).astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   States Affected               37 non-null     object
#  1   No. of Cases (Lab Confirmed)  37 non-null     int32
#  2   No. of Cases (on admission)   37 non-null     int32
#  3   No. Discharged                37 non-null     object
#  4   No. of Deaths                 37 non-null     int64
# dtypes: int32(2), int64(1), object(2)
# memory usage: 1.3+ KB

# %%
#Convert No. Discharged object to integer
df['No. Discharged'] = df['No. Discharged'].astype(str).astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   States Affected               37 non-null     object
#  1   No. of Cases (Lab Confirmed)  37 non-null     int32
#  2   No. of Cases (on admission)   37 non-null     int32
#  3   No. Discharged                37 non-null     int32
#  4   No. of Deaths                 37 non-null     int64
# dtypes: int32(3), int64(1), object(1)
# memory usage: 1.1+ KB

# %% [markdown]
# Observation: Memory usage has been reduced drastically base on the result above

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   States Affected               37 non-null     object
#  1   No. of Cases (Lab Confirmed)  37 non-null     object
#  2   No. of Cases (on admission)   37 non-null     object
#  3   No. Discharged                37 non-null     object
#  4   No. of Deaths                 37 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 1.6+ KB

# %%
# Remove the comma in No. of Cases No. of Cases (Lab Confirmed) column
df['No. of Cases (Lab Confirmed)'] = df['No. of Cases (Lab Confirmed)'].str.replace(',','')
df
# Out:
#    States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# 0            Lagos                        26708                       2,435
# 1              FCT                         9627                       2,840
# 2           Kaduna                         4504                         579
# 3          Plateau                         4262                         280
# 4              Oyo                         3788                         368
# 5           Rivers                         3279                         232
# 6              Edo                         2768                          52
# 7             Ogun                         2382                         174
# 8             Kano                         2032                         198
# 9            Delta                         1843                          57
# 10            Ondo                         1793                          62
# ...

# %%
# Remove the comma in No. of Cases (on admission) column
df['No. of Cases (on admission)']=df['No. of Cases (on admission)'].str.replace(',','')
df
# Out:
#    States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# 0            Lagos                        26708                        2435
# 1              FCT                         9627                        2840
# 2           Kaduna                         4504                         579
# 3          Plateau                         4262                         280
# 4              Oyo                         3788                         368
# 5           Rivers                         3279                         232
# 6              Edo                         2768                          52
# 7             Ogun                         2382                         174
# 8             Kano                         2032                         198
# 9            Delta                         1843                          57
# 10            Ondo                         1793                          62
# ...

# %%
# Remove the comma in No. Discharged column
df['No. Discharged']=df['No. Discharged'].str.replace(',','')
df
# Out:
#    States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# 0            Lagos                        26708                        2435
# 1              FCT                         9627                        2840
# 2           Kaduna                         4504                         579
# 3          Plateau                         4262                         280
# 4              Oyo                         3788                         368
# 5           Rivers                         3279                         232
# 6              Edo                         2768                          52
# 7             Ogun                         2382                         174
# 8             Kano                         2032                         198
# 9            Delta                         1843                          57
# 10            Ondo                         1793                          62
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   States Affected               37 non-null     object
#  1   No. of Cases (Lab Confirmed)  37 non-null     object
#  2   No. of Cases (on admission)   37 non-null     object
#  3   No. Discharged                37 non-null     object
#  4   No. of Deaths                 37 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 1.6+ KB

# %%
#df['No. of Cases (Lab Confirmed)'].mean()

# %%
df['No. of Cases (Lab Confirmed)'] = df['No. of Cases (Lab Confirmed)'].astype(str).astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   States Affected               37 non-null     object
#  1   No. of Cases (Lab Confirmed)  37 non-null     int32
#  2   No. of Cases (on admission)   37 non-null     object
#  3   No. Discharged                37 non-null     object
#  4   No. of Deaths                 37 non-null     int64
# dtypes: int32(1), int64(1), object(3)
# memory usage: 1.4+ KB

# %%
df['No. of Cases (on admission)'] = df['No. of Cases (on admission)'].astype(str).astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   States Affected               37 non-null     object
#  1   No. of Cases (Lab Confirmed)  37 non-null     int32
#  2   No. of Cases (on admission)   37 non-null     int32
#  3   No. Discharged                37 non-null     object
#  4   No. of Deaths                 37 non-null     int64
# dtypes: int32(2), int64(1), object(2)
# memory usage: 1.3+ KB

# %%
df['No. Discharged'] = df['No. Discharged'].astype(str).astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   States Affected               37 non-null     object
#  1   No. of Cases (Lab Confirmed)  37 non-null     int32
#  2   No. of Cases (on admission)   37 non-null     int32
#  3   No. Discharged                37 non-null     int32
#  4   No. of Deaths                 37 non-null     int64
# dtypes: int32(3), int64(1), object(1)
# memory usage: 1.1+ KB

# %%
# Extract the average of discharged
df['No. Discharged'].mean()
# Out:
# 1846.027027027027

# %%
# Extract the highest number of discharged
df['No. Discharged'].max()
# Out:
# 24037

# %%
# Extract the least number of discharged
df['No. Discharged'].min()
# Out:
# 3

# %%
# Extract the middle number of discharged
df['No. Discharged'].median()
# Out:
# 775.0

# %%
# Extract the total average of discharged
df['No. of Cases (Lab Confirmed)'].mean()
# Out:
# 2119.837837837838

# %%
# Extract the max of discharged
df['No. of Cases (Lab Confirmed)'].max()
# Out:
# 26708

# %%
# Extract the least of discharged
df['No. of Cases (Lab Confirmed)'].min()
# Out:
# 5

# %%
# Extract the median of discharged
df['No. of Cases (Lab Confirmed)'].median()
# Out:
# 897.0

# %%
#Extract the average number of No. of Cases (on admission)
df['No. of Cases (on admission)'].mean()
# Out:
# 240.8108108108108

# %%
#Extract the highest of No. of Cases (on admission)
df['No. of Cases (on admission)'].max()
# Out:
# 2840

# %%
#Extract the least of No. of Cases (on admission)
df['No. of Cases (on admission)'].min()
# Out:
# 0

# %%
#Extract the median of No. of Cases (on admission)
df['No. of Cases (on admission)'].median()
# Out:
# 57.0

# %%
df.isna().sum()
# Out:
# States Affected                 0
# No. of Cases (Lab Confirmed)    0
# No. of Cases (on admission)     0
# No. Discharged                  0
# No. of Deaths                   0
# dtype: int64

# %%
#df.plot.pie(y = 'States Affected', figsize = (4, 4))
#plt.title('Pie Chart')

# %%
#Plot scatter plot between mean area and mean smoothness
sns.scatterplot(x = 'No. of Cases (Lab Confirmed)', y = 'No. of Cases (on admission)', data = df)
# Out:
# <AxesSubplot:xlabel='No. of Cases (Lab Confirmed)', ylabel='No. of Cases (on admission)'>

# %%
#Plot scatter plot between mean area and mean smoothness
sns.scatterplot(x = 'No. of Cases (Lab Confirmed)', y = 'No. of Deaths', data = df)
# Out:
# <AxesSubplot:xlabel='No. of Cases (Lab Confirmed)', ylabel='No. of Deaths'>

# %%
#Plot scatter plot between mean area and mean smoothness
sns.scatterplot(x = 'No. of Cases (on admission)', y = 'No. of Deaths', data = df)
# Out:
# <AxesSubplot:xlabel='No. of Cases (on admission)', ylabel='No. of Deaths'>

# %%
#Plot scatter plot between mean area and mean smoothness
sns.scatterplot(x = 'States Affected', y = 'No. of Deaths', data = df)
# Out:
# <AxesSubplot:xlabel='States Affected', ylabel='No. of Deaths'>

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   States Affected               37 non-null     object
#  1   No. of Cases (Lab Confirmed)  37 non-null     int32
#  2   No. of Cases (on admission)   37 non-null     int32
#  3   No. Discharged                37 non-null     int32
#  4   No. of Deaths                 37 non-null     int64
# dtypes: int32(3), int64(1), object(1)
# memory usage: 1.1+ KB

# %%
# Plot the pairplot
sns.pairplot(df, vars=['No. of Cases (Lab Confirmed)', 'No. of Cases (on admission)'])

# %%
# Plot the pairplot
sns.pairplot(df, vars=['No. of Cases (Lab Confirmed)', 'No. of Cases (on admission)', 'No. Discharged', 'No. of Deaths'])

# %%
#Distribution plot
sns.distplot(df['No. of Deaths'],bins = 5, color = 'blue')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='No. of Deaths', ylabel='Density'>

# %%
#Distribution plot
sns.distplot(df['No. of Cases (Lab Confirmed)'],bins = 5, color = 'blue')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='No. of Cases (Lab Confirmed)', ylabel='Density'>

# %%
df.head(2)
# Out:
#   States Affected No. of Cases (Lab Confirmed) No. of Cases (on admission)  \
# 0           Lagos                       26,708                       2,435
# 1             FCT                        9,627                       2,840
#
#   No. Discharged  No. of Deaths
# 0         24,037            236
# 1          6,694             93

# %%
df.describe()
# Out:
#        No. of Deaths
# count      37.000000
# mean       33.000000
# std        41.797794
# min         2.000000
# 25%        11.000000
# 50%        21.000000
# 75%        36.000000
# max       236.000000

# %%
#Extract the number of death
print(df['No. of Deaths'].nunique())
# Out:
# 30

# %%
print(df['States Affected'].nunique())
# Out:
# 37

# %%
print(df['No. of Cases (Lab Confirmed)'].nunique())
# Out:
# 37

# %%
print(df['No. of Cases (on admission)'].unique())
# Out:
# ['2,435' '2,840' '579' '280' '368' '232' '52' '174' '198' '57' '62' '214'
#  '34' '171' '183' '24' '25' '20' '108' '37' '61' '262' '44' '55' '69' '96'
#  '6' '40' '19' '33' '5' '1' '0']

# %%
print(df['No. of Cases (on admission)'].nunique())
# Out:
# 33

# %%
print(df['No. Discharged'].unique())
# Out:
# ['24,037' '6,694' '3,877' '3,948' '3,374' '2,987' '2,603' '2,175' '1,778'
#  '1,737' '1,690' '1,167' '1,321' '1,094' '950' '1,037' '945' '937' '775'
#  '705' '661' '325' '460' '421' '375' '342' '318' '300' '238' '274' '171'
#  '177' '123' '130' '81' '73' '3']

# %%
print(df['No. Discharged'].nunique())
# Out:
# 37

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [States Affected, No. of Cases (Lab Confirmed), No. of Cases (on admission), No. Discharged, No. of Deaths]
# Index: []

# %%
# Create a Figure
fig = plt.figure(figsize=(8, 3))

# Create a bar plot of name vs grade
plt.bar(x=df['States Affected'], height=df['No. of Deaths'], color='#1fab2c')

# Customize the chart
plt.title('Nigeria Covid19 Analysis')
plt.xlabel('Affected State')
plt.ylabel('Number of Death')
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xticks(rotation=99)
plt.show()

# %% [markdown]
# Comments:
# * From the bar chart above, it is shown that:
#     * Lagos state has the highest number of death rate while Kogi state has the least

# %%
# Get the variable to examine
var_data = df['No. of Deaths']

# Create a Figure
fig = plt.figure(figsize=(10, 4))

# Plot a histogram
plt.hist(var_data)

# Add titles and labels
plt.title('Data Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

#Show the figure
fig.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18444\1506398083.py:16: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# Create a function that we can re-use
def show_distribution(var_data):
    '''
    This function will make a distribution (graph) and display it
    '''
    # Get statistics
    min_val = var_data.min()
    max_val = var_data.max()
    mean_val = var_data.mean()
    med_val = var_data.median()
    mod_val = var_data.mode()[0]

    print('Minimum:{:.2f}\nMean:{:.2f}\nMedian:{:.2f}\nMode:{:.2f}\nMaximum:{:.2f}\n'.format(min_val,
                                                                                            mean_val,
                                                                                            med_val,
                                                                                            mod_val,
                                                                                            max_val))
    # Create a figure for 2 subplots (2 rows, 1 column)
    fig, ax = plt.subplots(2, 1, figsize = (10, 4))
    
    # Plot the histogram 
    ax[0].hist(var_data)
    ax[0].set_ylabel('Frequency')
    
    # Add lines for the mean, median, and mode
    ax[0].axvline(x=min_val, color = 'purple', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=mean_val, color = 'cyan', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=med_val, color = 'red', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=mod_val, color = 'yellow', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=max_val, color = 'gray', linestyle='dashed', linewidth = 2)

    # Plot the boxplot 
    ax[1].boxplot(var_data, vert=False)
    ax[1].set_xlabel('Value')
    
    # Add a title to the Figure
    fig.suptitle('Data Distribution')
    
    # Show the figure
    fig.show()

show_distribution(df['No. of Deaths'])
# Out:
# Minimum:2.00
# Mean:33.00
# Median:21.00
# Mode:11.00
# Maximum:236.00
# C:\Users\user\AppData\Local\Temp\ipykernel_18444\229836350.py:40: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# Comments:
# * The yellow dash vertical line signifies mode(most occurrence) rate of death
# * The dashed vertical red line signifies median(middle) rate of death
# * The dashed vertical cyan line signifies mean rate of death
# * The dashed vertical red line signifies median(middle) rate of death
# * The dashed vertical purple line signifies least rate of death
# * The dashed vertical gray line signifies highest rate of death
