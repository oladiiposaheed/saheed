# %%
import pandas as pd
import numpy as np
from glob import glob
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
files = sorted(glob('*_Branch.csv'))
files
# Out:
# ['Abuja_Branch.csv', 'Lagos_Branch.csv', 'Port_Harcourt_Branch.csv']

# %%
csv_file = pd.concat((pd.read_csv(file) for file in files), ignore_index=True)
csv_file.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date   Time Payment  \
# 0     19742.4         3   2961.36   62188.56  2/20/2019  13:27    Card
# 1      5212.8         4   1042.56   21893.76   2/6/2019  18:07    Epay
# 2      9183.6         4   1836.72   38571.12   3/9/2019  17:03    Cash
# 3     33739.2         6  10121.76  212556.96  1/15/2019  16:19    Cash
# 4     14508.0         2   1450.80   30466.80  3/11/2019  15:30    Epay
#
#        cogs  gross margin percentage  gross income  Rating
# 0   59227.2                 4.761905       2961.36     5.9
# 1   20851.2                 4.761905       1042.56     4.5
# 2   36734.4                 4.761905       1836.72     6.8
# 3  202435.2                 4.761905      10121.76     4.5
# 4   29016.0                 4.761905       1450.80     4.4

# %% [markdown]
# ## Step 2 - Data Exploration
# * Use the head() method to view first few rows of the dataset
# * Check the number of rows and columns present in the data using the shape attribute.
# * Generate the names of the columns using the columns attribute.
# * Use describe function to generate the statistical summary of the dataframe
# * Use meaningful sentences to describe findings from the data statistical summary
# * Use of correct method to check for Missing values
# * Check the information of the DataFrame using the info method.

# %%
csv_file.to_csv( "csv_file.csv", index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv('csv_file.csv')
df.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date   Time Payment  \
# 0     19742.4         3   2961.36   62188.56  2/20/2019  13:27    Card
# 1      5212.8         4   1042.56   21893.76   2/6/2019  18:07    Epay
# 2      9183.6         4   1836.72   38571.12   3/9/2019  17:03    Cash
# 3     33739.2         6  10121.76  212556.96  1/15/2019  16:19    Cash
# 4     14508.0         2   1450.80   30466.80  3/11/2019  15:30    Epay
#
#        cogs  gross margin percentage  gross income  Rating
# 0   59227.2                 4.761905       2961.36     5.9
# 1   20851.2                 4.761905       1042.56     4.5
# 2   36734.4                 4.761905       1836.72     6.8
# 3  202435.2                 4.761905      10121.76     4.5
# 4   29016.0                 4.761905       1450.80     4.4

# %%
#Check the number of rows and columns present in the data using the shape attribute.
df.shape
# Out:
# (1000, 17)

# %%
#Total number of columns
df.shape[1]
# Out:
# 17

# %%
#Total number of columns
df.shape[1]
# Out:
# 17

# %%
#Generate the names of the columns using the columns attribute
list(df.columns)
# Out:
# ['Invoice ID',
#  'Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Unit price',
#  'Quantity',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'Payment',
#  'cogs',
#  'gross margin percentage',
#  'gross income',
#  'Rating']

# %%
#Generate the names of the columns using iterating over columns and find the total number of columns
count = 0
for col in df.columns:
    count += 1
    print(col)
    pass
print('There are {} columns'.format(count))
# Out:
# Invoice ID
# Branch
# City
# Customer type
# Gender
# Product line
# Unit price
# Quantity
# Tax 5%
# Total
# Date
# Time
# Payment
# cogs
# gross margin percentage
# gross income
# Rating
# There are 17 columns

# %%
#Use describe function to generate the statistical summary of the dataframe
print(df.describe())
# Out:
#          Unit price     Quantity        Tax 5%          Total           cogs  \
# count   1000.000000  1000.000000   1000.000000    1000.000000    1000.000000
# mean   20041.966800     5.510000   5536.572840  116268.029640  110731.456800
# std     9538.066205     2.923431   4215.177173   88518.720636   84303.543463
# min     3628.800000     1.000000    183.060000    3844.260000    3661.200000
# 25%    11835.000000     3.000000   2132.955000   44792.055000   42659.100000
# 50%    19882.800000     5.000000   4351.680000   91385.280000   87033.600000
# 75%    28056.600000     8.000000   8080.290000  169686.090000  161605.800000
# max    35985.600000    10.000000  17874.000000  375354.000000  357480.000000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00   5536.572840     6.97270
# std               6.131498e-14   4215.177173     1.71858
# min               4.761905e+00    183.060000     4.00000
# 25%               4.761905e+00   2132.955000     5.50000
# 50%               4.761905e+00   4351.680000     7.00000
# 75%               4.761905e+00   8080.290000     8.50000
# max               4.761905e+00  17874.000000    10.00000

# %%
#Use of correct method to check for Missing values
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.isnull().sum().tail()
# Out:
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Invoice ID                 1000
# Branch                     1000
# City                       1000
# Customer type              1000
# Gender                     1000
# Product line               1000
# Unit price                 1000
# Quantity                   1000
# Tax 5%                     1000
# Total                      1000
# Date                       1000
# Time                       1000
# Payment                    1000
# cogs                       1000
# gross margin percentage    1000
# gross income               1000
# Rating                     1000
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Invoice ID                 1000
# Branch                     1000
# City                       1000
# Customer type              1000
# Gender                     1000
# Product line               1000
# Unit price                 1000
# Quantity                   1000
# Tax 5%                     1000
# Total                      1000
# Date                       1000
# Time                       1000
# Payment                    1000
# cogs                       1000
# gross margin percentage    1000
# gross income               1000
# Rating                     1000
# dtype: int64

# %%
#Check the information of the DataFrame using the info method
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %% [markdown]
# ## Step 3 - Dealing with DateTime Features
# * Use to_datetime() to convert the date column to datetime
# * Check the datatype to confirm if it's in datetime
# * Accurate conversion of the time column & prints appropriate data type
# * Accurate extraction of the Day, Month, Year & Hour features
# * The numbers of unique hours of sales in the supermarket are accurately determined.
# * Result that shows an array that contains the unique sales hours

# %%
df.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date                Time  \
# 0     19742.4         3   2961.36   62188.56  2/20/2019 2022-12-20 13:27:00
# 1      5212.8         4   1042.56   21893.76   2/6/2019 2022-12-20 18:07:00
# 2      9183.6         4   1836.72   38571.12   3/9/2019 2022-12-20 17:03:00
# 3     33739.2         6  10121.76  212556.96  1/15/2019 2022-12-20 16:19:00
# 4     14508.0         2   1450.80   30466.80  3/11/2019 2022-12-20 15:30:00
#
#   Payment      cogs  gross margin percentage  gross income  Rating
# 0    Card   59227.2                 4.761905       2961.36     5.9
# 1    Epay   20851.2                 4.761905       1042.56     4.5
# 2    Cash   36734.4                 4.761905       1836.72     6.8
# 3    Cash  202435.2                 4.761905      10121.76     4.5
# 4    Epay   29016.0                 4.761905       1450.80     4.4

# %%
#Use to_datetime() to convert the date column to datetime
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date                Time  \
# 0     19742.4         3   2961.36   62188.56 2019-02-20 2022-12-20 13:27:00
# 1      5212.8         4   1042.56   21893.76 2019-02-06 2022-12-20 18:07:00
# 2      9183.6         4   1836.72   38571.12 2019-03-09 2022-12-20 17:03:00
# 3     33739.2         6  10121.76  212556.96 2019-01-15 2022-12-20 16:19:00
# 4     14508.0         2   1450.80   30466.80 2019-03-11 2022-12-20 15:30:00
#
#   Payment      cogs  gross margin percentage  gross income  Rating
# 0    Card   59227.2                 4.761905       2961.36     5.9
# 1    Epay   20851.2                 4.761905       1042.56     4.5
# 2    Cash   36734.4                 4.761905       1836.72     6.8
# 3    Cash  202435.2                 4.761905      10121.76     4.5
# 4    Epay   29016.0                 4.761905       1450.80     4.4

# %%
df['Date']
# Out:
# 0     2019-02-20
# 1     2019-02-06
# 2     2019-03-09
# 3     2019-01-15
# 4     2019-03-11
#          ...
# 995   2019-01-23
# 996   2019-01-09
# 997   2019-03-29
# 998   2019-02-18
# 999   2019-01-29
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
#Check the datatype to confirm if it's in datetime
print(df['Date'].dtype)
# Out:
# datetime64[ns]

# %%
df['Time'] = pd.to_datetime(df['Time'])
df.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date                Time  \
# 0     19742.4         3   2961.36   62188.56 2019-02-20 2022-12-20 13:27:00
# 1      5212.8         4   1042.56   21893.76 2019-02-06 2022-12-20 18:07:00
# 2      9183.6         4   1836.72   38571.12 2019-03-09 2022-12-20 17:03:00
# 3     33739.2         6  10121.76  212556.96 2019-01-15 2022-12-20 16:19:00
# 4     14508.0         2   1450.80   30466.80 2019-03-11 2022-12-20 15:30:00
#
#   Payment      cogs  gross margin percentage  gross income  Rating
# 0    Card   59227.2                 4.761905       2961.36     5.9
# 1    Epay   20851.2                 4.761905       1042.56     4.5
# 2    Cash   36734.4                 4.761905       1836.72     6.8
# 3    Cash  202435.2                 4.761905      10121.76     4.5
# 4    Epay   29016.0                 4.761905       1450.80     4.4

# %%
df['Time'] = df['Time'].dt.time
df.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date      Time Payment  \
# 0     19742.4         3   2961.36   62188.56 2019-02-20  13:27:00    Card
# 1      5212.8         4   1042.56   21893.76 2019-02-06  18:07:00    Epay
# 2      9183.6         4   1836.72   38571.12 2019-03-09  17:03:00    Cash
# 3     33739.2         6  10121.76  212556.96 2019-01-15  16:19:00    Cash
# 4     14508.0         2   1450.80   30466.80 2019-03-11  15:30:00    Epay
#
#        cogs  gross margin percentage  gross income  Rating
# 0   59227.2                 4.761905       2961.36     5.9
# 1   20851.2                 4.761905       1042.56     4.5
# 2   36734.4                 4.761905       1836.72     6.8
# 3  202435.2                 4.761905      10121.76     4.5
# 4   29016.0                 4.761905       1450.80     4.4

# %%
df['Year'] = df['Date'].dt.year
df.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date      Time Payment  \
# 0     19742.4         3   2961.36   62188.56 2019-02-20  13:27:00    Card
# 1      5212.8         4   1042.56   21893.76 2019-02-06  18:07:00    Epay
# 2      9183.6         4   1836.72   38571.12 2019-03-09  17:03:00    Cash
# 3     33739.2         6  10121.76  212556.96 2019-01-15  16:19:00    Cash
# 4     14508.0         2   1450.80   30466.80 2019-03-11  15:30:00    Epay
#
#        cogs  gross margin percentage  gross income  Rating  Year
# 0   59227.2                 4.761905       2961.36     5.9  2019
# 1   20851.2                 4.761905       1042.56     4.5  2019
# 2   36734.4                 4.761905       1836.72     6.8  2019
# 3  202435.2                 4.761905      10121.76     4.5  2019
# 4   29016.0                 4.761905       1450.80     4.4  2019

# %%
df['Month'] = df['Date'].dt.month
df.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date      Time Payment  \
# 0     19742.4         3   2961.36   62188.56 2019-02-20  13:27:00    Card
# 1      5212.8         4   1042.56   21893.76 2019-02-06  18:07:00    Epay
# 2      9183.6         4   1836.72   38571.12 2019-03-09  17:03:00    Cash
# 3     33739.2         6  10121.76  212556.96 2019-01-15  16:19:00    Cash
# 4     14508.0         2   1450.80   30466.80 2019-03-11  15:30:00    Epay
#
#        cogs  gross margin percentage  gross income  Rating  Year  Month
# 0   59227.2                 4.761905       2961.36     5.9  2019      2
# 1   20851.2                 4.761905       1042.56     4.5  2019      2
# 2   36734.4                 4.761905       1836.72     6.8  2019      3
# 3  202435.2                 4.761905      10121.76     4.5  2019      1
# 4   29016.0                 4.761905       1450.80     4.4  2019      3

# %%
#Extraction of the Day, Month, Year & Hour features
df['Date'].dt.month_name()
# Out:
# 0      February
# 1      February
# 2         March
# 3       January
# 4         March
#          ...
# 995     January
# 996     January
# 997       March
# 998    February
# 999     January
# Name: Date, Length: 1000, dtype: object

# %%
#Extraction of the Day
df['Date'].dt.day_name()
# Out:
# 0      Wednesday
# 1      Wednesday
# 2       Saturday
# 3        Tuesday
# 4         Monday
#          ...
# 995    Wednesday
# 996    Wednesday
# 997       Friday
# 998       Monday
# 999      Tuesday
# Name: Date, Length: 1000, dtype: object

# %%
#Extraction of the Year
df['Date'].dt.year
# Out:
# 0      2019
# 1      2019
# 2      2019
# 3      2019
# 4      2019
#        ...
# 995    2019
# 996    2019
# 997    2019
# 998    2019
# 999    2019
# Name: Date, Length: 1000, dtype: int64

# %%
#df['Minute'] = df['Time'].dt.minute
#df
df.isnull().sum() # To check null values
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# Year                       0
# Month                      0
# dtype: int64

# %%
#df['Year'] = df['Date'].dt.year
#df.head()

# %%
print(df.City.unique())
# Out:
# ['Abuja' 'Lagos' 'Port Harcourt']

# %%
print(df.Time.unique())
# Out:
# [datetime.time(13, 27) datetime.time(18, 7) datetime.time(17, 3)
#  datetime.time(16, 19) datetime.time(15, 30) datetime.time(10, 40)
#  datetime.time(12, 20) datetime.time(15, 31) datetime.time(19, 48)
#  datetime.time(19, 39) datetime.time(12, 43) datetime.time(14, 49)
#  datetime.time(13, 1) datetime.time(18, 45) datetime.time(13, 3)
#  datetime.time(18, 0) datetime.time(17, 24) datetime.time(15, 47)
#  datetime.time(12, 45) datetime.time(14, 42) datetime.time(11, 49)
#  datetime.time(13, 40) datetime.time(14, 35) datetime.time(15, 1)
#  datetime.time(18, 17) datetime.time(19, 56) datetime.time(17, 55)
#  datetime.time(12, 9) datetime.time(10, 25) datetime.time(18, 14)
#  datetime.time(18, 19) datetime.time(11, 32) datetime.time(12, 44)
#  datetime.time(12, 29) datetime.time(15, 26) datetime.time(20, 38)
#  datetime.time(17, 26) datetime.time(14, 57) datetime.time(11, 15)
#  datetime.time(13, 18) datetime.time(18, 36) datetime.time(14, 40)
#  datetime.time(12, 21) datetime.time(15, 7) datetime.time(19, 20)
#  datetime.time(19, 40) datetime.time(13, 58) datetime.time(14, 43)
#  datetime.time(19, 18) datetime.time(15, 24) datetime.time(14, 12)
#  datetime.time(17, 34) datetime.time(12, 4) datetime.time(19, 46)
#  datetime.time(19, 0) datetime.time(10, 53) datetime.time(10, 39)
#  datetime.time(13, 41) datetime.time(20, 23) datetime.time(11, 57)
#  datetime.time(14, 51) datetime.time(12, 42) datetime.time(19, 42)
#  datetime.time(19, 17) datetime.time(13, 24) datetime.time(15, 53)
#  datetime.time(18, 27) datetime.time(12, 58) datetime.time(18, 59)
#  datetime.time(13, 44) datetime.time(13, 46) datetime.time(19, 14)
#  datetime.time(10, 52) datetime.time(19, 28) datetime.time(13, 52)
#  datetime.time(10, 54) datetime.time(18, 31) datetime.time(19, 26)
#  datetime.time(18, 42) datetime.time(19, 43) datetime.time(19, 6)
#  datetime.time(15, 34) datetime.time(19, 22) datetime.time(19, 24)
#  datetime.time(20, 55) datetime.time(18, 13) datetime.time(16, 52)
#  datetime.time(20, 52) datetime.time(18, 1) datetime.time(13, 30)
#  datetime.time(17, 37) datetime.time(11, 46) datetime.time(16, 46)
#  datetime.time(14, 4) datetime.time(19, 53) datetime.time(10, 11)
#  datetime.time(18, 48) datetime.time(13, 2) datetime.time(18, 23)
#  datetime.time(20, 21) datetime.time(11, 6) datetime.time(19, 2)
#  datetime.time(14, 16) datetime.time(15, 40) datetime.time(16, 58)
#  datetime.time(19, 50) datetime.time(13, 32) datetime.time(13, 19)
#  datetime.time(10, 26) datetime.time(16, 28) datetime.time(10, 43)
#  datetime.time(19, 1) datetime.time(13, 0) datetime.time(14, 29)
#  datetime.time(17, 13) datetime.time(13, 53) datetime.time(17, 27)
#  datetime.time(14, 36) datetime.time(19, 35) datetime.time(17, 58)
#  datetime.time(20, 7) datetime.time(11, 2) datetime.time(19, 7)
#  datetime.time(18, 50) datetime.time(16, 59) datetime.time(14, 15)
#  datetime.time(20, 24) datetime.time(12, 25) datetime.time(18, 33)
#  datetime.time(15, 25) datetime.time(13, 21) datetime.time(11, 48)
#  datetime.time(14, 14) datetime.time(17, 36) datetime.time(17, 53)
#  datetime.time(16, 36) datetime.time(12, 50) datetime.time(10, 48)
#  datetime.time(14, 28) datetime.time(18, 3) datetime.time(16, 48)
#  datetime.time(10, 34) datetime.time(20, 3) datetime.time(14, 55)
#  datetime.time(11, 28) datetime.time(12, 14) datetime.time(20, 40)
#  datetime.time(17, 45) datetime.time(20, 31) datetime.time(10, 49)
#  datetime.time(12, 34) datetime.time(13, 45) datetime.time(19, 38)
#  datetime.time(12, 32) datetime.time(10, 33) datetime.time(17, 16)
#  datetime.time(19, 55) datetime.time(19, 49) datetime.time(18, 43)
#  datetime.time(12, 15) datetime.time(15, 58) datetime.time(13, 5)
#  datetime.time(11, 30) datetime.time(13, 54) datetime.time(10, 37)
#  datetime.time(11, 45) datetime.time(19, 51) datetime.time(15, 27)
#  datetime.time(11, 25) datetime.time(15, 42) datetime.time(16, 4)
#  datetime.time(14, 41) datetime.time(11, 29) datetime.time(20, 0)
#  datetime.time(15, 8) datetime.time(18, 22) datetime.time(11, 52)
#  datetime.time(18, 4) datetime.time(13, 6) datetime.time(20, 43)
#  datetime.time(10, 1) datetime.time(16, 34) datetime.time(13, 10)
#  datetime.time(19, 57) datetime.time(19, 29) datetime.time(11, 59)
#  datetime.time(19, 11) datetime.time(18, 57) datetime.time(11, 18)
#  datetime.time(12, 40) datetime.time(14, 6) datetime.time(20, 48)
#  datetime.time(15, 4) datetime.time(20, 42) datetime.time(18, 53)
#  datetime.time(17, 49) datetime.time(10, 38) datetime.time(11, 16)
#  datetime.time(15, 5) datetime.time(15, 28) datetime.time(15, 12)
#  datetime.time(13, 59) datetime.time(18, 51) datetime.time(11, 58)
#  datetime.time(18, 8) datetime.time(13, 7) datetime.time(20, 32)
#  datetime.time(13, 48) datetime.time(16, 26) datetime.time(10, 50)
#  datetime.time(16, 45) datetime.time(11, 12) datetime.time(14, 38)
#  datetime.time(16, 32) datetime.time(11, 36) datetime.time(18, 37)
#  datetime.time(11, 1) datetime.time(20, 8) datetime.time(17, 38)
#  datetime.time(19, 31) datetime.time(13, 51) datetime.time(11, 55)
#  datetime.time(11, 42) datetime.time(14, 48) datetime.time(11, 51)
#  datetime.time(20, 19) datetime.time(10, 17) datetime.time(14, 25)
#  datetime.time(15, 18) datetime.time(15, 6) datetime.time(20, 57)
#  datetime.time(15, 16) datetime.time(17, 47) datetime.time(12, 2)
#  datetime.time(14, 8) datetime.time(10, 44) datetime.time(20, 29)
#  datetime.time(11, 26) datetime.time(12, 36) datetime.time(10, 58)
#  datetime.time(11, 10) datetime.time(20, 51) datetime.time(13, 33)
#  datetime.time(20, 13) datetime.time(14, 26) datetime.time(13, 22)
#  datetime.time(15, 55) datetime.time(18, 18) datetime.time(19, 44)
#  datetime.time(15, 17) datetime.time(15, 10) datetime.time(18, 10)
#  datetime.time(19, 30) datetime.time(19, 8) datetime.time(15, 46)
#  datetime.time(18, 35) datetime.time(13, 8) datetime.time(13, 23)
#  datetime.time(20, 33) datetime.time(17, 15) datetime.time(19, 21)
#  datetime.time(11, 3) datetime.time(12, 17) datetime.time(15, 36)
#  datetime.time(10, 12) datetime.time(19, 15) datetime.time(17, 17)
#  datetime.time(12, 27) datetime.time(16, 40) datetime.time(10, 4)
#  datetime.time(10, 55) datetime.time(15, 48) datetime.time(20, 35)
#  datetime.time(16, 57) datetime.time(16, 42) datetime.time(10, 16)
#  datetime.time(16, 44) datetime.time(14, 50) datetime.time(18, 44)
#  datetime.time(13, 26) datetime.time(20, 34) datetime.time(20, 59)
#  datetime.time(15, 39) datetime.time(19, 25) datetime.time(16, 37)
#  datetime.time(12, 28) datetime.time(11, 56) datetime.time(16, 21)
#  datetime.time(16, 20) datetime.time(16, 31) datetime.time(17, 1)
#  datetime.time(19, 16) datetime.time(11, 19) datetime.time(10, 13)
#  datetime.time(16, 55) datetime.time(15, 56) datetime.time(12, 55)
#  datetime.time(18, 24) datetime.time(18, 9) datetime.time(11, 20)
#  datetime.time(16, 49) datetime.time(12, 1) datetime.time(14, 47)
#  datetime.time(16, 11) datetime.time(11, 22) datetime.time(11, 23)
#  datetime.time(10, 46) datetime.time(12, 38) datetime.time(13, 25)
#  datetime.time(11, 0) datetime.time(16, 5) datetime.time(13, 34)
#  datetime.time(11, 44) datetime.time(15, 51) datetime.time(11, 9)
#  datetime.time(15, 2) datetime.time(14, 21) datetime.time(10, 0)
#  datetime.time(15, 54) datetime.time(20, 14) datetime.time(17, 9)
#  datetime.time(17, 43) datetime.time(10, 8) datetime.time(13, 12)
#  datetime.time(12, 48) datetime.time(19, 9) datetime.time(15, 59)
#  datetime.time(11, 21) datetime.time(15, 49) datetime.time(16, 10)
#  datetime.time(17, 44) datetime.time(10, 29) datetime.time(12, 46)
#  datetime.time(16, 47) datetime.time(12, 52) datetime.time(10, 36)
#  datetime.time(20, 36) datetime.time(18, 55) datetime.time(19, 36)
#  datetime.time(10, 23) datetime.time(15, 37) datetime.time(15, 9)
#  datetime.time(13, 47) datetime.time(11, 40) datetime.time(17, 4)
#  datetime.time(18, 20) datetime.time(20, 54) datetime.time(17, 29)
#  datetime.time(18, 5) datetime.time(12, 7) datetime.time(13, 55)
#  datetime.time(16, 3) datetime.time(19, 41) datetime.time(13, 28)
#  datetime.time(16, 23) datetime.time(12, 8) datetime.time(10, 28)
#  datetime.time(16, 54) datetime.time(14, 33) datetime.time(19, 54)
#  datetime.time(14, 3) datetime.time(16, 38) datetime.time(12, 23)
#  datetime.time(14, 13) datetime.time(14, 22) datetime.time(12, 56)
#  datetime.time(10, 18) datetime.time(12, 24) datetime.time(12, 37)
#  datetime.time(14, 19) datetime.time(17, 46) datetime.time(15, 44)
#  datetime.time(10, 22) datetime.time(18, 30) datetime.time(13, 57)
#  datetime.time(12, 22) datetime.time(17, 59) datetime.time(19, 45)
#  datetime.time(20, 26) datetime.time(20, 18) datetime.time(16, 6)
#  datetime.time(12, 47) datetime.time(19, 33) datetime.time(11, 39)
#  datetime.time(15, 29) datetime.time(10, 31) datetime.time(12, 30)
#  datetime.time(15, 19) datetime.time(17, 48) datetime.time(11, 7)
#  datetime.time(16, 9) datetime.time(15, 15) datetime.time(20, 6)
#  datetime.time(11, 27) datetime.time(18, 41) datetime.time(17, 12)
#  datetime.time(18, 6) datetime.time(14, 0) datetime.time(10, 57)
#  datetime.time(10, 10) datetime.time(10, 5) datetime.time(18, 15)
#  datetime.time(15, 21) datetime.time(16, 16) datetime.time(13, 11)
#  datetime.time(11, 5) datetime.time(12, 35) datetime.time(14, 30)
#  datetime.time(13, 35) datetime.time(16, 8) datetime.time(13, 37)
#  datetime.time(10, 3) datetime.time(13, 14) datetime.time(17, 35)
#  datetime.time(16, 30) datetime.time(10, 9) datetime.time(17, 54)
#  datetime.time(16, 27) datetime.time(14, 53) datetime.time(15, 23)
#  datetime.time(18, 2) datetime.time(20, 46) datetime.time(15, 33)
#  datetime.time(11, 38) datetime.time(11, 24) datetime.time(10, 42)
#  datetime.time(20, 39) datetime.time(19, 47) datetime.time(17, 8)
#  datetime.time(10, 19) datetime.time(15, 43) datetime.time(18, 21)
#  datetime.time(14, 20) datetime.time(16, 24) datetime.time(18, 56)
#  datetime.time(14, 31) datetime.time(20, 5) datetime.time(10, 41)
#  datetime.time(19, 52) datetime.time(16, 17) datetime.time(15, 57)
#  datetime.time(16, 43) datetime.time(17, 11) datetime.time(16, 7)
#  datetime.time(15, 0) datetime.time(20, 50) datetime.time(19, 58)
#  datetime.time(10, 2) datetime.time(17, 7) datetime.time(17, 22)
#  datetime.time(13, 29) datetime.time(17, 20) datetime.time(13, 42)
#  datetime.time(14, 44) datetime.time(10, 21) datetime.time(19, 5)
#  datetime.time(11, 34) datetime.time(18, 58) datetime.time(20, 1)
#  datetime.time(20, 37) datetime.time(12, 12) datetime.time(15, 32)
#  datetime.time(12, 31) datetime.time(20, 4) datetime.time(13, 38)
#  datetime.time(17, 30) datetime.time(16, 53) datetime.time(16, 51)
#  datetime.time(20, 15) datetime.time(14, 11) datetime.time(12, 10)
#  datetime.time(20, 47) datetime.time(11, 17) datetime.time(15, 52)
#  datetime.time(11, 43) datetime.time(10, 30) datetime.time(10, 6)
#  datetime.time(12, 16) datetime.time(14, 58) datetime.time(14, 45)
#  datetime.time(17, 10) datetime.time(14, 27) datetime.time(12, 51)
#  datetime.time(13, 56) datetime.time(16, 18) datetime.time(15, 14)
#  datetime.time(20, 10) datetime.time(14, 24) datetime.time(12, 39)
#  datetime.time(12, 41) datetime.time(15, 20) datetime.time(16, 33)
#  datetime.time(20, 44) datetime.time(20, 30) datetime.time(16, 50)
#  datetime.time(17, 52) datetime.time(11, 33) datetime.time(18, 38)
#  datetime.time(15, 11) datetime.time(15, 45) datetime.time(16, 35)
#  datetime.time(13, 50) datetime.time(17, 56) datetime.time(13, 49)
#  datetime.time(14, 5) datetime.time(19, 12)]

# %% [markdown]
# ## Step 4 - Unique Values in Columns
# * Appropriate method to generate the unique values in the categorical columns (apart from the example - Branch column).
# * Generated the count figure of the categorical values using the value_counts() method.

# %%
df.head(1)
# Out:
#                 Invoice ID Branch Customer type  Gender        Product line  \
# City  Payment
# Abuja Card     692-92-5582      B        Member  Female  Food and beverages
#
#                Unit price  Quantity   Tax 5%     Total       Date   Time  \
# City  Payment
# Abuja Card        19742.4         3  2961.36  62188.56  2/20/2019  13:27
#
#                   cogs  gross margin percentage  gross income  Rating
# City  Payment
# Abuja Card     59227.2                 4.761905       2961.36     5.9

# %%
print(df['Product line'].unique())
# Out:
# ['Food and beverages' 'Fashion accessories' 'Electronic accessories'
#  'Sports and travel' 'Home and lifestyle' 'Health and beauty']

# %%
print(df['Payment'].unique())
# Out:
# ['Card' 'Epay' 'Cash']

# %%
print(df['Customer type'].unique())
# Out:
# ['Member' 'Normal']

# %%
print(df['Customer type'].nunique())
# Out:
# 2

# %%
print(df['Payment'].nunique())
# Out:
# 3

# %%
print(df['Product line'].nunique())
# Out:
# 6

# %% [markdown]
# ## Step 5 - Aggregation with GroupBy
# * A groupby object with the "City Column", and aggregation function of sum and mean.
# * A table that shows the gross income of each city, and determines the city with the highest total gross income.
# * Optional - Use of appropriate methods & descriptions to explore other columns such as Unit Price, Quantity.

# %%
df.groupby('City').agg(['sum', 'mean'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1360\1412606682.py:1: FutureWarning: ['Invoice ID', 'Branch', 'Customer type', 'Gender', 'Product line', 'Date', 'Time', 'Payment'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby('City').agg(['sum', 'mean'])
#               Unit price               Quantity                Tax 5%  \
#                      sum          mean      sum      mean         sum
# City
# Abuja          6652396.8  20037.339759     1820  5.481928  1820531.52
# Lagos          6705176.4  19721.107059     1859  5.467647  1820577.78
# Port Harcourt  6684393.6  20379.248780     1831  5.582317  1895463.54
#
#                                   Total                       cogs  \
#                       mean          sum           mean         sum
# City
# Abuja          5483.528675  38231161.92  115154.102169  36410630.4
# Lagos          5354.640529  38232133.38  112447.451118  36411555.6
# Port Harcourt  5778.852256  39804734.34  121355.897378  37909270.8
#
#                              gross margin percentage           gross income  \
#                         mean                     sum      mean          sum
# City
# Abuja          109670.573494             1580.952381  4.761905   1820531.52
# Lagos          107092.810588             1619.047619  4.761905   1820577.78
# Port Harcourt  115577.045122             1561.904762  4.761905   1895463.54
#
#                             Rating              Year         Month
#                       mean     sum      mean     sum    mean   sum      mean
# City
# Abuja          5483.528675  2263.6  6.818072  670308  2019.0   665  2.003012
# Lagos          5354.640529  2389.2  7.027059  686460  2019.0   688  2.023529
# Port Harcourt  5778.852256  2319.9  7.072866  662232  2019.0   640  1.951220

# %%
#A table that shows the gross income of each city 

# Get the sum of the durations per month
df.groupby('City')['gross income'].sum().reset_index()
# Out:
#             City  gross income
# 0          Abuja    1820531.52
# 1          Lagos    1820577.78
# 2  Port Harcourt    1895463.54

# %% [markdown]
# ## Step 6 - Data Visualization
# * Appropriate use of countplot to determine the branch with the highest sales record.
# * Optional - Appropriate use of countplot to determine the most used payment method & city with the most sales.
# * Appropriate use of countplot to determine the highest & lowest sold product line.
# * Result that shows the Payment channel used by most customers to pay for each product line. Chart should also show the "product line" column on the Y-axis, and the "hue" parameter for the "Payment" column.

# %%
#determines the city with the highest total gross income.
df.groupby("City")['gross income'].sum().reset_index().max().reset_index()
# Out:
#           index              0
# 0          City  Port Harcourt
# 1  gross income     1895463.54

# %%
df.groupby('City').mean()
# Out:
#                  Unit price  Quantity       Tax 5%          Total  \
# City
# Abuja          20037.339759  5.481928  5483.528675  115154.102169
# Lagos          19721.107059  5.467647  5354.640529  112447.451118
# Port Harcourt  20379.248780  5.582317  5778.852256  121355.897378
#
#                         cogs  gross margin percentage  gross income    Rating  \
# City
# Abuja          109670.573494                 4.761905   5483.528675  6.818072
# Lagos          107092.810588                 4.761905   5354.640529  7.027059
# Port Harcourt  115577.045122                 4.761905   5778.852256  7.072866
#
#                  Year     Month
# City
# Abuja          2019.0  2.003012
# Lagos          2019.0  2.023529
# Port Harcourt  2019.0  1.951220

# %%
df.groupby('City')["Unit price", "Quantity", 'gross income', "gross margin percentage"].sum()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1360\2257243174.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('City')["Unit price", "Quantity", 'gross income', "gross margin percentage"].sum()
#                Unit price  Quantity  gross income  gross margin percentage
# City
# Abuja           6652396.8      1820    1820531.52              1580.952381
# Lagos           6705176.4      1859    1820577.78              1619.047619
# Port Harcourt   6684393.6      1831    1895463.54              1561.904762

# %%
#import seaborn as sns
sns.countplot(x='Branch', hue='City', data = df, palette = 'Set2').set_title('Branch with Sales', size=15);

# %%
sns.countplot(x='Branch', data=df).set_title('Branches', size=15);

# %%
#Plotting bar horizontal
sns.countplot(y='Branch', hue='City', data=df).set_title('Card Payment', size=15);

# %%
#payment method & city
sns.countplot(x='Payment', hue='Payment', data=df, palette = "Set3").set_title('Card Payment', size=15);

# %%
#payment method & city
sns.countplot(x='Payment', data=df, palette = "Set1").set_title('Card Payment', size=25);

# %%
#highest & lowest sold product line.
sns.countplot(y='Product line', data=df, palette='Spectral_r', saturation = 0.9).set_title('Sale and its Product Lines', size=20)
# Out:
# Text(0.5, 1.0, 'Sale and its Product Lines')

# %% [markdown]
# * Highest product sale is Food and beverages
# * Lowest product sale is Health and beauty

# %%
#highest & lowest sold product line.
sns.countplot(y='Product line', hue='Payment', data=df, palette='Spectral_r', saturation = 0.9).set_title('Payment Method and its Product Lines', size=20)
# Out:
# Text(0.5, 1.0, 'Payment Method and its Product Lines')

# %%
#payment method & city with the most sales.
sns.countplot(x='Payment', data=df, hue='City').set_title('Payment Method and City', size=24)
# Out:
# Text(0.5, 1.0, 'Payment Method and City')

# %% [markdown]
# * Port Harcourt has the highest payment method follow by Lagos

# %%
#Payment method and branch
sns.countplot(x='Payment', data=df, hue='Branch').set_title('Payment Method and Branch', size=24)
# Out:
# Text(0.5, 1.0, 'Payment Method and Branch')

# %%
df.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date   Time Payment  \
# 0     19742.4         3   2961.36   62188.56  2/20/2019  13:27    Card
# 1      5212.8         4   1042.56   21893.76   2/6/2019  18:07    Epay
# 2      9183.6         4   1836.72   38571.12   3/9/2019  17:03    Cash
# 3     33739.2         6  10121.76  212556.96  1/15/2019  16:19    Cash
# 4     14508.0         2   1450.80   30466.80  3/11/2019  15:30    Epay
#
#        cogs  gross margin percentage  gross income  Rating
# 0   59227.2                 4.761905       2961.36     5.9
# 1   20851.2                 4.761905       1042.56     4.5
# 2   36734.4                 4.761905       1836.72     6.8
# 3  202435.2                 4.761905      10121.76     4.5
# 4   29016.0                 4.761905       1450.80     4.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB

# %%
# Create a function that we can re-use
def show_distribution(var_data):
    '''
    This function will make a distribution (graph) and display it
    '''
    # Get statistics
    min_val = var_data.min()
    max_val = var_data.max()
    mean_val = var_data.mean()
    med_val = var_data.median()
    mod_val = var_data.mode()[0]

    print('Minimum:{:.2f}\nMean:{:.2f}\nMedian:{:.2f}\nMode:{:.2f}\nMaximum:{:.2f}\n'.format(min_val,
                                                                                            mean_val,
                                                                                            med_val,
                                                                                            mod_val,
                                                                                            max_val))
    # Create a figure for 2 subplots (2 rows, 1 column)
    fig, ax = plt.subplots(2, 1, figsize = (10, 4))
    
    # Plot the histogram 
    ax[0].hist(var_data)
    ax[0].set_ylabel('Frequency')
    
    # Add lines for the mean, median, and mode
    ax[0].axvline(x=min_val, color = 'gray', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=mean_val, color = 'cyan', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=med_val, color = 'red', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=mod_val, color = 'yellow', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=max_val, color = 'gray', linestyle='dashed', linewidth = 2)

    # Plot the boxplot 
    ax[1].boxplot(var_data, vert=False)
    ax[1].set_xlabel('Value')
    
    # Add a title to the Figure
    fig.suptitle('Data Distribution')
    
    # Show the figure
    fig.show()

show_distribution(df['gross income'])
# Out:
# Minimum:183.06
# Mean:5536.57
# Median:4351.68
# Mode:1495.44
# Maximum:17874.00
# C:\Users\user\AppData\Local\Temp\ipykernel_14260\2758081578.py:40: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
col = df['Unit price']
# Call the function
show_distribution(col)
# Out:
# Minimum:3628.80
# Mean:20041.97
# Median:19882.80
# Mode:30157.20
# Maximum:35985.60
# C:\Users\user\AppData\Local\Temp\ipykernel_14260\2758081578.py:40: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# Get the variable to examine
# We will only get students who have studied more than one hour
col = df[df.Quantity > 1]['Quantity']
# Call the function
show_distribution(col)
# Out:
# Minimum:2.00
# Mean:6.08
# Median:6.00
# Mode:10.00
# Maximum:10.00
# C:\Users\user\AppData\Local\Temp\ipykernel_14260\2758081578.py:40: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
#Extract the 1st 4 columns
sample = df[['Branch', 'City', 'Customer type', 'Gender']]
sample
# Out:
#     Branch           City Customer type  Gender
# 0        B          Abuja        Member  Female
# 1        B          Abuja        Member  Female
# 2        B          Abuja        Member    Male
# 3        B          Abuja        Member  Female
# 4        B          Abuja        Normal  Female
# ..     ...            ...           ...     ...
# 995      C  Port Harcourt        Normal    Male
# 996      C  Port Harcourt        Normal    Male
# 997      C  Port Harcourt        Member    Male
# 998      C  Port Harcourt        Member  Female
# 999      C  Port Harcourt        Normal    Male
#
# [1000 rows x 4 columns]

# %%
#Plot scatter plot between cogs and Unit price
sns.scatterplot(x = 'Unit price', y = 'cogs', hue = 'City', data = df)
# Out:
# <AxesSubplot:xlabel='Unit price', ylabel='cogs'>

# %% [markdown]
# Comments:
# * Unit price is directly proportional as cogs
# * As the Unit price increases, corrresponding value of cogs also increases
# * From the graph, Port harcourt has highest Unit price which is above 35000$ and highest cogs above 350000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB

# %%
sns.scatterplot(x = 'gross margin percentage', y = 'gross income', data=df)
# Out:
# <AxesSubplot:xlabel='gross margin percentage', ylabel='gross income'>

# %%
# Plot the pairplot
sns.pairplot(df, vars=['gross margin percentage', 'gross income', 'cogs', 'Rating'])

# %%
# Strong correlation 
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## GroupBy

# %%
#calculate the mean for each of the city
df.groupby('City')['Unit price', 'Date'].mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14260\209756069.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('City')['Unit price', 'Date'].mean()
#                  Unit price
# City
# Abuja          20037.339759
# Lagos          19721.107059
# Port Harcourt  20379.248780

# %%
#Extract the city with the highest unit price
df.groupby('City')['Unit price', 'Date'].max()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14260\1259646932.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('City')['Unit price', 'Date'].max()
#                Unit price      Date
# City
# Abuja             35985.6  3/9/2019
# Lagos             35938.8  3/9/2019
# Port Harcourt     35985.6  3/9/2019

# %%
#Extract the city with the least unit price
df.groupby('City')['Unit price', 'Date'].min()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14260\1617604091.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('City')['Unit price', 'Date'].min()
#                Unit price      Date
# City
# Abuja              3812.4  1/1/2019
# Lagos              3628.8  1/1/2019
# Port Harcourt      3657.6  1/1/2019

# %%
#calculate the standard deviation for each of the city
df.groupby('City')['Unit price', 'Date'].std()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14260\3847787993.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('City')['Unit price', 'Date'].std()
#                 Unit price
# City
# Abuja          9440.841216
# Lagos          9407.565699
# Port Harcourt  9784.727668

# %%
df.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date   Time Payment  \
# 0     19742.4         3   2961.36   62188.56  2/20/2019  13:27    Card
# 1      5212.8         4   1042.56   21893.76   2/6/2019  18:07    Epay
# 2      9183.6         4   1836.72   38571.12   3/9/2019  17:03    Cash
# 3     33739.2         6  10121.76  212556.96  1/15/2019  16:19    Cash
# 4     14508.0         2   1450.80   30466.80  3/11/2019  15:30    Epay
#
#        cogs  gross margin percentage  gross income  Rating
# 0   59227.2                 4.761905       2961.36     5.9
# 1   20851.2                 4.761905       1042.56     4.5
# 2   36734.4                 4.761905       1836.72     6.8
# 3  202435.2                 4.761905      10121.76     4.5
# 4   29016.0                 4.761905       1450.80     4.4

# %%
df.set_index(keys=['City', 'Payment'], inplace=True)
df
# Out:
#                         Invoice ID Branch Customer type  Gender  \
# City          Payment
# Abuja         Card     692-92-5582      B        Member  Female
#               Epay     351-62-0822      B        Member  Female
#               Cash     529-56-3974      B        Member    Male
#               Cash     299-46-1805      B        Member  Female
#               Epay     319-50-3348      B        Normal  Female
# ...                            ...    ...           ...     ...
# Port Harcourt Cash     148-41-7930      C        Normal    Male
#               Cash     189-40-5216      C        Normal    Male
#               Epay     267-62-7380      C        Member    Male
#               Epay     652-49-6720      C        Member  Female
#               Epay     233-67-5758      C        Normal    Male
#
#                                  Product line  Unit price  Quantity    Tax 5%  \
# City          Payment
# Abuja         Card         Food and beverages     19742.4         3   2961.36
#               Epay        Fashion accessories      5212.8         4   1042.56
#               Cash     Electronic accessories      9183.6         4   1836.72
#               Cash          Sports and travel     33739.2         6  10121.76
#               Epay         Home and lifestyle     14508.0         2   1450.80
# ...                                       ...         ...       ...       ...
# Port Harcourt Cash          Health and beauty     35985.6         7  12594.96
#               Cash     Electronic accessories     34693.2         7  12142.62
#               Epay     Electronic accessories     29642.4        10  14821.20
#               Epay     Electronic accessories     21942.0         1   1097.10
#               Epay          Health and beauty     14526.0         1    726.30
#
#                            Total       Date   Time      cogs  \
# City          Payment
# Abuja         Card      62188.56  2/20/2019  13:27   59227.2
#               Epay      21893.76   2/6/2019  18:07   20851.2
#               Cash      38571.12   3/9/2019  17:03   36734.4
#               Cash     212556.96  1/15/2019  16:19  202435.2
#               Epay      30466.80  3/11/2019  15:30   29016.0
# ...                          ...        ...    ...       ...
# Port Harcourt Cash     264494.16  1/23/2019  10:33  251899.2
#               Cash     254995.02   1/9/2019  11:40  242852.4
#               Epay     311245.20  3/29/2019  19:12  296424.0
#               Epay      23039.10  2/18/2019  11:40   21942.0
#               Epay      15252.30  1/29/2019  13:46   14526.0
#
#                        gross margin percentage  gross income  Rating
# City          Payment
# Abuja         Card                    4.761905       2961.36     5.9
#               Epay                    4.761905       1042.56     4.5
#               Cash                    4.761905       1836.72     6.8
#               Cash                    4.761905      10121.76     4.5
#               Epay                    4.761905       1450.80     4.4
# ...                                        ...           ...     ...
# Port Harcourt Cash                    4.761905      12594.96     6.1
#               Cash                    4.761905      12142.62     6.0
#               Epay                    4.761905      14821.20     4.3
#               Epay                    4.761905       1097.10     5.9
#               Epay                    4.761905        726.30     6.2
#
# [1000 rows x 15 columns]

# %%
# Transpose indexes and columns
df.transpose().head()
# Out:
# City                        Abuja                       \
# Payment                      Card                 Epay
# Invoice ID            692-92-5582          351-62-0822
# Branch                          B                    B
# Customer type              Member               Member
# Gender                     Female               Female
# Product line   Food and beverages  Fashion accessories
#
# City                                                                          \
# Payment                          Cash               Cash                Epay
# Invoice ID                529-56-3974        299-46-1805         319-50-3348
# Branch                              B                  B                   B
# Customer type                  Member             Member              Normal
# Gender                           Male             Female              Female
# Product line   Electronic accessories  Sports and travel  Home and lifestyle
#
# City                                                                       \
# Payment                     Epay                Card                 Cash
# Invoice ID           371-85-5789         273-16-6619          649-29-6775
# Branch                         B                   B                    B
# Customer type             Normal              Normal               Normal
# Gender                      Male                Male                 Male
# Product line   Health and beauty  Home and lifestyle  Fashion accessories
#
# City                                                    ...  \
# Payment                      Cash                 Card  ...
# Invoice ID            145-94-9061          871-79-8483  ...
# Branch                          B                    B  ...
# Customer type              Normal               Normal  ...
# Gender                     Female                 Male  ...
# Product line   Food and beverages  Fashion accessories  ...
#
# City                Port Harcourt                       \
# Payment                      Cash                 Cash
# Invoice ID            867-47-1948          256-58-3609
# Branch                          C                    C
# Customer type              Normal               Member
# Gender                     Female                 Male
# Product line   Home and lifestyle  Fashion accessories
#
# City                                                        \
# Payment                          Cash                 Cash
# Invoice ID                364-34-2972          744-82-9138
# Branch                              C                    C
# Customer type                  Member               Normal
# Gender                           Male                 Male
# Product line   Electronic accessories  Fashion accessories
#
# City                                                                          \
# Payment                      Cash               Cash                    Cash
# Invoice ID            728-47-9078        148-41-7930             189-40-5216
# Branch                          C                  C                       C
# Customer type              Member             Normal                  Normal
# Gender                       Male               Male                    Male
# Product line   Food and beverages  Health and beauty  Electronic accessories
#
# City                                                           \
# Payment                          Epay                    Epay
# Invoice ID                267-62-7380             652-49-6720
# Branch                              C                       C
# Customer type                  Member                  Member
# Gender                           Male                  Female
# Product line   Electronic accessories  Electronic accessories
#
# City
# Payment                     Epay
# Invoice ID           233-67-5758
# Branch                         C
# Customer type             Normal
# Gender                      Male
# Product line   Health and beauty
#
# [5 rows x 1000 columns]

# %%
df.head(3)
# Out:
#                 Invoice ID Branch Customer type  Gender  \
# City  Payment
# Abuja Card     692-92-5582      B        Member  Female
#       Epay     351-62-0822      B        Member  Female
#       Cash     529-56-3974      B        Member    Male
#
#                          Product line  Unit price  Quantity   Tax 5%  \
# City  Payment
# Abuja Card         Food and beverages     19742.4         3  2961.36
#       Epay        Fashion accessories      5212.8         4  1042.56
#       Cash     Electronic accessories      9183.6         4  1836.72
#
#                   Total       Date   Time     cogs  gross margin percentage  \
# City  Payment
# Abuja Card     62188.56  2/20/2019  13:27  59227.2                 4.761905
#       Epay     21893.76   2/6/2019  18:07  20851.2                 4.761905
#       Cash     38571.12   3/9/2019  17:03  36734.4                 4.761905
#
#                gross income  Rating
# City  Payment
# Abuja Card          2961.36     5.9
#       Epay          1042.56     4.5
#       Cash          1836.72     6.8

# %%
df.iloc[4]
# Out:
# Invoice ID                        319-50-3348
# Branch                                      B
# Customer type                          Normal
# Gender                                 Female
# Product line               Home and lifestyle
# Unit price                            14508.0
# Quantity                                    2
# Tax 5%                                 1450.8
# Total                                 30466.8
# Date                                3/11/2019
# Time                                    15:30
# cogs                                  29016.0
# gross margin percentage              4.761905
# gross income                           1450.8
# Rating                                    4.4
# Name: (Abuja, Epay), dtype: object

# %%
df.iloc[2:5]
# Out:
#                 Invoice ID Branch Customer type  Gender  \
# City  Payment
# Abuja Cash     529-56-3974      B        Member    Male
#       Cash     299-46-1805      B        Member  Female
#       Epay     319-50-3348      B        Normal  Female
#
#                          Product line  Unit price  Quantity    Tax 5%  \
# City  Payment
# Abuja Cash     Electronic accessories      9183.6         4   1836.72
#       Cash          Sports and travel     33739.2         6  10121.76
#       Epay         Home and lifestyle     14508.0         2   1450.80
#
#                    Total       Date   Time      cogs  gross margin percentage  \
# City  Payment
# Abuja Cash      38571.12   3/9/2019  17:03   36734.4                 4.761905
#       Cash     212556.96  1/15/2019  16:19  202435.2                 4.761905
#       Epay      30466.80  3/11/2019  15:30   29016.0                 4.761905
#
#                gross income  Rating
# City  Payment
# Abuja Cash          1836.72     6.8
#       Cash         10121.76     4.5
#       Epay          1450.80     4.4

# %%
#Check for missing value
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Invoice ID, Branch, Customer type, Gender, Product line, Unit price, Quantity, Tax 5%, Total, Date, Time, cogs, gross margin percentage, gross income, Rating]
# Index: []

# %% [markdown]
# Comment:
# * No missing value

# %%
# Create a Figure
fig = plt.figure(figsize=(8, 3))

# Create a bar plot of name vs grade
plt.bar(x=df.Gender, height=df.cogs, color='orange')

# Customize the chart
plt.title('Bar Chart')
plt.xlabel('City')
plt.ylabel('Cogs')
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xticks(rotation=99)
plt.show()

# %%
# Create a Figure
fig = plt.figure(figsize=(8, 3))

# Create a bar plot of name vs grade
plt.bar(x=df.Gender, height=df.Quantity, color='orange')

# Customize the chart
plt.title('Bar Chart')
plt.xlabel('Gender')
plt.ylabel('Quantity')
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xticks(rotation=90)
plt.show()

# %%
# Create a Figure
fig = plt.figure(figsize=(8, 3))

# Create a bar plot of name vs grade
plt.bar(x=df.Gender, height=df.Rating, color='orange')

# Customize the chart
plt.title('Bar Chart')
plt.xlabel('Gender')
plt.ylabel('Rating')
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xticks(rotation=99)
plt.show()

# %%
# Get the variable to examine

var = df['Unit price']

# Create a Figure
fig = plt.figure(figsize=(10,4))

# Plot a histogram
plt.boxplot(var)

# Add titles and labels
plt.title('Data Distribution')

# Show the figure
fig.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14260\2180611942.py:15: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
def show_density(var_data):
    from matplotlib import pyplot as plt

    fig = plt.figure(figsize=(10,4))

    # Plot density
    var_data.plot.density()

    # Add titles and labels
    plt.title('Data Density')

    # Show the mean, median, and mode
    plt.axvline(x=var_data.mean(), color = 'cyan', linestyle='dashed', linewidth = 2)
    plt.axvline(x=var_data.median(), color = 'red', linestyle='dashed', linewidth = 2)
    plt.axvline(x=var_data.mode()[0], color = 'yellow', linestyle='dashed', linewidth = 2)

    # Show the figure
    plt.show()

# Get the density of Grade
col = df['Unit price']
show_density(col)

# %%
df.describe()
# Out:
#          Unit price     Quantity        Tax 5%          Total           cogs  \
# count   1000.000000  1000.000000   1000.000000    1000.000000    1000.000000
# mean   20041.966800     5.510000   5536.572840  116268.029640  110731.456800
# std     9538.066205     2.923431   4215.177173   88518.720636   84303.543463
# min     3628.800000     1.000000    183.060000    3844.260000    3661.200000
# 25%    11835.000000     3.000000   2132.955000   44792.055000   42659.100000
# 50%    19882.800000     5.000000   4351.680000   91385.280000   87033.600000
# 75%    28056.600000     8.000000   8080.290000  169686.090000  161605.800000
# max    35985.600000    10.000000  17874.000000  375354.000000  357480.000000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00   5536.572840     6.97270
# std               6.131498e-14   4215.177173     1.71858
# min               4.761905e+00    183.060000     4.00000
# 25%               4.761905e+00   2132.955000     5.50000
# 50%               4.761905e+00   4351.680000     7.00000
# 75%               4.761905e+00   8080.290000     8.50000
# max               4.761905e+00  17874.000000    10.00000
